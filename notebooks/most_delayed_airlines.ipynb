# %%
# spark.stop()

# %%
import sys
sys.path.append('/Users/nf/Documents/Projects/SkyLake')

from spark import config

session = config.Session()
spark = session.get_spark_session()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# :: loading settings :: url = jar:file:/Users/nf/Documents/Projects/SkyLake/.venv/lib/python3.14/site-packages/pyspark/jars/ivy-2.5.3.jar!/org/apache/ivy/core/settings/ivysettings.xml
# Ivy Default Cache set to: /Users/nf/.ivy2.5.2/cache
# The jars for the packages stored in: /Users/nf/.ivy2.5.2/jars
# org.apache.hadoop#hadoop-aws added as a dependency
# com.amazonaws#aws-java-sdk-bundle added as a dependency
# org.apache.iceberg#iceberg-spark-runtime-4.0_2.13 added as a dependency
# :: resolving dependencies :: org.apache.spark#spark-submit-parent-ad456bd9-e699-47e4-aeed-dcb3eeda49a8;1.0
# 	confs: [default]
# 	found org.apache.hadoop#hadoop-aws;3.4.1 in central
# 	found software.amazon.awssdk#bundle;2.24.6 in central
# 	found org.wildfly.openssl#wildfly-openssl;1.1.3.Final in central
# 	found com.amazonaws#aws-java-sdk-bundle;1.12.262 in central
# 	found org.apache.iceberg#iceberg-spark-runtime-4.0_2.13;1.10.2 in central
# ...

# %%
# "Which airline delays most?"

spark.sql('''
    SELECT
        OP_CARRIER,
        ROUND(AVG(ARR_DELAY), 2) AS avg_delay,
        COUNT(*) AS total_flights
    FROM local.flights.flight_events
    WHERE ARR_DELAY > 0
    GROUP BY OP_CARRIER
    ORDER BY avg_delay DESC
    LIMIT 10
''').show()
